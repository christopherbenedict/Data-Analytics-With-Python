# %% [markdown]
# # Lesson 6 Class Exercises: More Practice

# %% [markdown]
# We will use today's class exercise to reinforce the learning we've done to this point

# %% [markdown]
# ## Get Started
# Import the Numpy and Pandas packages

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# Read in the apple data found in the `data/apple_data.tsv` directory.

# %%
apple = pd.read_csv('data/apple_data.tsv', delimiter='\t')
apple.head(5)
# Out:
#            State    1982    1987    1992    1997    2002    2007     1982  \
# 0        Alabama    899     626     474     479     265     231    1,548
# 1         Alaska      --      --      2       4       9      10        --
# 2        Arizona    214     224     235     158     185     496    1,969
# 3       Arkansas    512     451     247     238     164     153    2,276
# 4     California  2,904   2,787   3,082   3,454   2,120   2,074   29,933
#
#       1987   1992.1   1997.1   2002.1   2007.1 2002.2 2007.2  2002.3  2007.3
# 0   1,217    1,011      968      594      393     191    144     386     307
# 1       --      (D)       2       13       15       8     10     (D)     (D)
# 2   4,881    5,770    4,003    1,581    1,344     118    424   1,459   1,249
# 3   2,120    1,430    1,048      658      287     123    116     560     220
# 4  34,105   42,024   49,704   38,268   22,184   1,850  1,850  35,856  20,954

# %% [markdown]
# Explore the data using the approach we've used thus far:
# - List all of the column names
# - Identify the data types
# - Find the shape of the data
# - Explore categorical values -- do we have the expected number of values for each?
# - Get descriptive statistics for the numerical data
# - Do we have missing values?
# - Do we have duplicates?

# %%
apple.columns
# Out:
# Index(['       State', '1982', '1987', '1992', '1997', '2002', '2007',
#        '  1982', '  1987', '1992.1', '1997.1', '2002.1', '2007.1', '2002.2',
#        '2007.2', '2002.3', '2007.3'],
#       dtype='object')

# %%
apple.dtypes
# Out:
#        State    object
# 1982            object
# 1987            object
# 1992            object
# 1997            object
# 2002            object
# 2007            object
#   1982          object
#   1987          object
# 1992.1          object
# 1997.1          object
# 2002.1          object
# 2007.1          object
# 2002.2          object
# 2007.2          object
# 2002.3          object
# 2007.3          object
# dtype: object

# %%
apple.shape
# Out:
# (50, 17)

# %%
apple['       State'].unique()
# Out:
# array(['   Alabama', '   Alaska', '   Arizona', '   Arkansas',
#        '   California', '   Colorado', '   Connecticut', '   Delaware',
#        '   Florida', '   Georgia', '   Hawaii', '   Idaho', '   Illinois',
#        '   Indiana', '   Iowa', '   Kansas', '   Kentucky',
#        '   Louisiana', '   Maine', '   Maryland', '   Massachusetts',
#        '   Michigan', '   Minnesota', '   Mississippi', '   Missouri',
#        '   Montana', '   Nebraska', '   Nevada', '   New Hampshire',
#        '   New Jersey', '   New Mexico', '   New York',
#        '   North Carolina', '   North Dakota', '   Ohio', '   Oklahoma',
#        '   Oregon', '   Pennsylvania', '   Rhode Island',
#        '   South Carolina', '   South Dakota', '   Tennessee', '   Texas',
#        '   Utah', '   Vermont', '   Virginia', '   Washington',
#        '   West Virginia', '   Wisconsin', '   Wyoming'], dtype=object)

# %%
apple.describe()
# Out:
#               State 1982 1987  1992  1997  2002 2007   1982   1987 1992.1  \
# count            50   50   50    50    50    50   50     50     50     50
# unique           50   49   48    49    49    50   49     49     49     49
# top         Alabama   --   --  392   485   265   35      --     --    (D)
# freq              1    2    2     2     2     1    2      2      2      2
#
#         1997.1 2002.1 2007.1 2002.2 2007.2 2002.3 2007.3
# count       50     50     50     50     50     50     50
# unique      48     48     48     46     49     46     48
# top     5,389     (D)    (D)      8    427    (D)    (D)
# freq         2      3      3      2      2      5      3

# %%
apple.isna().sum()
# Out:
#        State    0
# 1982            0
# 1987            0
# 1992            0
# 1997            0
# 2002            0
# 2007            0
#   1982          0
#   1987          0
# 1992.1          0
# 1997.1          0
# 2002.1          0
# 2007.1          0
# 2002.2          0
# 2007.2          0
# 2002.3          0
# 2007.3          0
# dtype: int64

# %%
apple.duplicated().sum()
# Out:
# 0

# %% [markdown]
# What needs cleaning with the data?

# %% [raw]
# column headers have spacing
# column headers have spaces
# column headers need unique
# changing objects into numbers
# Address missing values

# %% [markdown]
# ### Clean the data

# %% [markdown]
# Re-read the file and make sure we have get the missing values correct.

# %%
apple = pd.read_csv("data/apple_data.tsv", delimiter="\t", na_values=["--","(D)"])
apple.head()
# Out:
#            State    1982    1987    1992    1997    2002    2007     1982  \
# 0        Alabama    899     626     474     479     265     231    1,548
# 1         Alaska     NaN     NaN      2       4       9      10       NaN
# 2        Arizona    214     224     235     158     185     496    1,969
# 3       Arkansas    512     451     247     238     164     153    2,276
# 4     California  2,904   2,787   3,082   3,454   2,120   2,074   29,933
#
#       1987   1992.1   1997.1   2002.1   2007.1 2002.2 2007.2  2002.3  2007.3
# 0   1,217    1,011      968      594      393     191    144     386     307
# 1      NaN      NaN       2       13       15       8     10     NaN     NaN
# 2   4,881    5,770    4,003    1,581    1,344     118    424   1,459   1,249
# 3   2,120    1,430    1,048      658      287     123    116     560     220
# 4  34,105   42,024   49,704   38,268   22,184   1,850  1,850  35,856  20,954

# %% [markdown]
# Make the column names correct

# %%
apple = apple.set_axis(['State', '1982_Farms', '1987_Farms', '1992_Farms', '1997_Farms', '2002_Farms', '2007_Farms', '1982_TTLAcres', '1987_TTLAcres', '1992_TTLAcres', '1997_TTLAcres', '2002_TTLAcres', '2007_TTLAcres', '2002_FarmBear_Acres', '2007_FarmBear_Acres', '2002_Bear_Acres', '2007_Bear_Acres' ], axis=1)
apple.head()
# Out:
#            State 1982_Farms 1987_Farms 1992_Farms 1997_Farms 2002_Farms  \
# 0        Alabama       899        626        474        479        265
# 1         Alaska        NaN        NaN         2          4          9
# 2        Arizona       214        224        235        158        185
# 3       Arkansas       512        451        247        238        164
# 4     California     2,904      2,787      3,082      3,454      2,120
#
#   2007_Farms 1982_TTLAcres 1987_TTLAcres 1992_TTLAcres 1997_TTLAcres  \
# 0       231         1,548         1,217         1,011           968
# 1        10            NaN           NaN           NaN            2
# 2       496         1,969         4,881         5,770         4,003
# 3       153         2,276         2,120         1,430         1,048
# 4     2,074        29,933        34,105        42,024        49,704
#
#   2002_TTLAcres 2007_TTLAcres 2002_FarmBear_Acres 2007_FarmBear_Acres  \
# 0          594           393                  191                 144
# 1           13            15                    8                  10
# 2        1,581         1,344                  118                 424
# 3          658           287                  123                 116
# 4       38,268        22,184                1,850               1,850
#
#   2002_Bear_Acres 2007_Bear_Acres
# 0             386             307
# 1             NaN             NaN
# 2           1,459           1,249
# 3             560             220
# 4          35,856          20,954

# %% [markdown]
# Next, remove commas. We need to alter the strings of multiple columns. We know how to do this within a single column, but how do we do this with multiple columns?  Remember the `apply()` function! We can apply any function we want.  We can't use the `pd.Series.str.replace()` function though because that belongs to the Pandas Series objects, we need an independent function. We can write our own!
#
# We can use the formal defintion (e.g.):
#
# ```python
# def remoteCommas(col):
#     return col.str.replace(',','')
#
# apple_data = apple_data.apply(remoteCommas)
# ```
#
# Or we can simplify it using Pythons `lambda` function definition. `lambda` is used to declare an in-line function.  It works just like a normal function but it does not have a name and is used for quick very short in-line functions.  For example:
#
# ```python
# apple_data = apple_data.apply(lambda x: x.str.replace(',',''))
# ```

# %%
apple = apple.apply(lambda x: x.str.replace(',',''))
apple.head()
# Out:
#            State 1982_Farms 1987_Farms 1992_Farms 1997_Farms 2002_Farms  \
# 0        Alabama       899        626        474        479        265
# 1         Alaska        NaN        NaN         2          4          9
# 2        Arizona       214        224        235        158        185
# 3       Arkansas       512        451        247        238        164
# 4     California      2904       2787       3082       3454       2120
#
#   2007_Farms 1982_TTLAcres 1987_TTLAcres 1992_TTLAcres 1997_TTLAcres  \
# 0       231          1548          1217          1011           968
# 1        10            NaN           NaN           NaN            2
# 2       496          1969          4881          5770          4003
# 3       153          2276          2120          1430          1048
# 4      2074         29933         34105         42024         49704
#
#   2002_TTLAcres 2007_TTLAcres 2002_FarmBear_Acres 2007_FarmBear_Acres  \
# 0          594           393                  191                 144
# 1           13            15                    8                  10
# 2         1581          1344                  118                 424
# 3          658           287                  123                 116
# 4        38268         22184                 1850                1850
#
#   2002_Bear_Acres 2007_Bear_Acres
# 0             386             307
# 1             NaN             NaN
# 2            1459            1249
# 3             560             220
# 4           35856           20954

# %% [markdown]
# Remove spaces preceeding the state names

# %%
apple['State'] = apple['State'].str.replace('   ','')
apple['State'].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia',
#        'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas',
#        'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts',
#        'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana',
#        'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico',
#        'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma',
#        'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina',
#        'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont',
#        'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'],
#       dtype=object)

# %% [markdown]
# Convert columns to numeric. Convert to floats instead of integers because NaNs are considered float values.

# %%
temp = apple.iloc[:,1:].apply(lambda x: x.astype('float'))
apple = pd.concat([apple['State'], temp], axis=1)
apple.head()


#apple.iloc[:,1:18]=apple.iloc[:,1:18].astype(float)
#apple.dtypes

#apple = apple.iloc[:,1:].astype(float)
#apple["State"]=apple["State"]
#apple.dtypes
#state = apple3['State'].astype('|S')
#state = apple3['1997_Farms'].astype('int64')
# Out:
#         State  1982_Farms  1987_Farms  1992_Farms  1997_Farms  2002_Farms  \
# 0     Alabama       899.0       626.0       474.0       479.0       265.0
# 1      Alaska         NaN         NaN         2.0         4.0         9.0
# 2     Arizona       214.0       224.0       235.0       158.0       185.0
# 3    Arkansas       512.0       451.0       247.0       238.0       164.0
# 4  California      2904.0      2787.0      3082.0      3454.0      2120.0
#
#    2007_Farms  1982_TTLAcres  1987_TTLAcres  1992_TTLAcres  1997_TTLAcres  \
# 0       231.0         1548.0         1217.0         1011.0          968.0
# 1        10.0            NaN            NaN            NaN            2.0
# 2       496.0         1969.0         4881.0         5770.0         4003.0
# 3       153.0         2276.0         2120.0         1430.0         1048.0
# 4      2074.0        29933.0        34105.0        42024.0        49704.0
#
#    2002_TTLAcres  2007_TTLAcres  2002_FarmBear_Acres  2007_FarmBear_Acres  \
# 0          594.0          393.0                191.0                144.0
# 1           13.0           15.0                  8.0                 10.0
# 2         1581.0         1344.0                118.0                424.0
# 3          658.0          287.0                123.0                116.0
# 4        38268.0        22184.0               1850.0               1850.0
#
#    2002_Bear_Acres  2007_Bear_Acres
# 0            386.0            307.0
# 1              NaN              NaN
# 2           1459.0           1249.0
# 3            560.0            220.0
# 4          35856.0          20954.0

# %% [markdown]
# Check the types to make sure all is good

# %% [markdown]
# Now desribe the numeric data

# %%
apple.describe()
# Out:
#        1982_Farms   1987_Farms   1992_Farms   1997_Farms   2002_Farms  \
# count    48.00000    48.000000    49.000000    49.000000    50.000000
# mean    858.06250   764.958333   691.408163   690.510204   537.060000
# std     989.94688   915.886408   851.933974   912.523975   692.712221
# min      24.00000    18.000000     2.000000     4.000000     2.000000
# 25%     237.00000   222.250000   235.000000   210.000000   168.750000
# 50%     531.50000   544.500000   474.000000   428.000000   338.500000
# 75%     932.00000   862.750000   782.000000   724.000000   578.250000
# max    5406.00000  5169.000000  4596.000000  4910.000000  3870.000000
#
#         2007_Farms  1982_TTLAcres  1987_TTLAcres  1992_TTLAcres  \
# count    50.000000      48.000000      48.000000      47.000000
# mean    511.820000   12302.979167   12521.354167   12416.255319
# std     606.840183   25304.382357   27199.429306   28246.151550
# min       9.000000      41.000000      33.000000      35.000000
# 25%     148.500000    1383.000000    1170.000000     999.000000
# 50%     333.000000    4086.500000    4536.500000    4332.000000
# 75%     562.500000    8642.000000    8791.250000    7407.000000
# max    3052.000000  145630.000000  162609.000000  169107.000000
#
#        1997_TTLAcres  2002_TTLAcres  2007_TTLAcres  2002_FarmBear_Acres  \
# count      47.000000      47.000000      47.000000            50.000000
# mean    12927.510638    9863.234043    8470.638298           421.680000
# std     34141.187355   27100.575228   25504.573629           613.202348
# min         2.000000       6.000000      15.000000             2.000000
# 25%       973.500000     596.500000     373.000000           119.250000
# 50%      3187.000000    2384.000000    2057.000000           232.500000
# 75%      6465.500000    4202.500000    3966.000000           400.750000
# max    215463.000000  172810.000000  165215.000000          3580.000000
#
#        2007_FarmBear_Acres  2002_Bear_Acres  2007_Bear_Acres
# count            50.000000        45.000000        47.000000
# mean            434.320000      8917.000000      7651.595745
# std             557.364954     24400.441667     23454.296203
# min               8.000000        19.000000         3.000000
# 25%             116.500000       470.000000       261.500000
# 50%             264.000000      2113.000000      1769.000000
# 75%             453.250000      4083.000000      3444.000000
# max            2912.000000    152241.000000    152334.000000

# %% [markdown]
# ### Explore the Data Again

# %% [markdown]
# Now that we have problems with the dataframe correct, let's explore. Are our data types correct?

# %%
apple.dtypes
# Out:
# State                   object
# 1982_Farms             float64
# 1987_Farms             float64
# 1992_Farms             float64
# 1997_Farms             float64
# 2002_Farms             float64
# 2007_Farms             float64
# 1982_TTLAcres          float64
# 1987_TTLAcres          float64
# 1992_TTLAcres          float64
# 1997_TTLAcres          float64
# 2002_TTLAcres          float64
# 2007_TTLAcres          float64
# 2002_FarmBear_Acres    float64
# 2007_FarmBear_Acres    float64
# 2002_Bear_Acres        float64
# 2007_Bear_Acres        float64
# dtype: object

# %% [markdown]
# Now that we have numeric data we can perform a proper summary

# %%
apple.describe()
# Out:
#        1982_Farms   1987_Farms   1992_Farms   1997_Farms   2002_Farms  \
# count    48.00000    48.000000    49.000000    49.000000    50.000000
# mean    858.06250   764.958333   691.408163   690.510204   537.060000
# std     989.94688   915.886408   851.933974   912.523975   692.712221
# min      24.00000    18.000000     2.000000     4.000000     2.000000
# 25%     237.00000   222.250000   235.000000   210.000000   168.750000
# 50%     531.50000   544.500000   474.000000   428.000000   338.500000
# 75%     932.00000   862.750000   782.000000   724.000000   578.250000
# max    5406.00000  5169.000000  4596.000000  4910.000000  3870.000000
#
#         2007_Farms  1982_TTLAcres  1987_TTLAcres  1992_TTLAcres  \
# count    50.000000      48.000000      48.000000      47.000000
# mean    511.820000   12302.979167   12521.354167   12416.255319
# std     606.840183   25304.382357   27199.429306   28246.151550
# min       9.000000      41.000000      33.000000      35.000000
# 25%     148.500000    1383.000000    1170.000000     999.000000
# 50%     333.000000    4086.500000    4536.500000    4332.000000
# 75%     562.500000    8642.000000    8791.250000    7407.000000
# max    3052.000000  145630.000000  162609.000000  169107.000000
#
#        1997_TTLAcres  2002_TTLAcres  2007_TTLAcres  2002_FarmBear_Acres  \
# count      47.000000      47.000000      47.000000            50.000000
# mean    12927.510638    9863.234043    8470.638298           421.680000
# std     34141.187355   27100.575228   25504.573629           613.202348
# min         2.000000       6.000000      15.000000             2.000000
# 25%       973.500000     596.500000     373.000000           119.250000
# 50%      3187.000000    2384.000000    2057.000000           232.500000
# 75%      6465.500000    4202.500000    3966.000000           400.750000
# max    215463.000000  172810.000000  165215.000000          3580.000000
#
#        2007_FarmBear_Acres  2002_Bear_Acres  2007_Bear_Acres
# count            50.000000        45.000000        47.000000
# mean            434.320000      8917.000000      7651.595745
# std             557.364954     24400.441667     23454.296203
# min               8.000000        19.000000         3.000000
# 25%             116.500000       470.000000       261.500000
# 50%             264.000000      2113.000000      1769.000000
# 75%             453.250000      4083.000000      3444.000000
# max            2912.000000    152241.000000    152334.000000

# %% [markdown]
# Do we have any missing values?

# %%
apple.isna().sum()
# Out:
# State                  0
# 1982_Farms             2
# 1987_Farms             2
# 1992_Farms             1
# 1997_Farms             1
# 2002_Farms             0
# 2007_Farms             0
# 1982_TTLAcres          2
# 1987_TTLAcres          2
# 1992_TTLAcres          3
# 1997_TTLAcres          3
# 2002_TTLAcres          3
# 2007_TTLAcres          3
# 2002_FarmBear_Acres    0
# 2007_FarmBear_Acres    0
# 2002_Bear_Acres        5
# 2007_Bear_Acres        3
# dtype: int64

# %% [markdown]
# Are missing values reasonable?  Should we remove any?

# %% [raw]
# No, they seem reasonable for now

# %% [markdown]
# Do we have any duplicated data?

# %%
apple.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Does our only categorical column have expected values?

# %%
apple['State'].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia',
#        'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas',
#        'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts',
#        'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana',
#        'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico',
#        'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma',
#        'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina',
#        'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont',
#        'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'],
#       dtype=object)

# %%
apple['State'].describe()
# Out:
# count          50
# unique         50
# top       Alabama
# freq            1
# Name: State, dtype: object

# %% [markdown]
# How many rows do we have per state?

# %% [markdown]
# Are the number of rows per state what we expect?

# %% [markdown]
# ### Tidy the data

# %% [markdown]
# What is/are the observable unit(s)?

# %% [raw]
# States

# %% [markdown]
# What are the variables?

# %% [raw]
# year, acereage, bearing acres, number of farms, bearing farms, state

# %% [markdown]
# What are the observations (values)?

# %% [raw]
# numeric year, count of acres, count of bearing acres, amount of bearing acres, number of farms, state name

# %%
apple.head()
# Out:
#         State  1982_Farms  1987_Farms  1992_Farms  1997_Farms  2002_Farms  \
# 0     Alabama       899.0       626.0       474.0       479.0       265.0
# 1      Alaska         NaN         NaN         2.0         4.0         9.0
# 2     Arizona       214.0       224.0       235.0       158.0       185.0
# 3    Arkansas       512.0       451.0       247.0       238.0       164.0
# 4  California      2904.0      2787.0      3082.0      3454.0      2120.0
#
#    2007_Farms  1982_TTLAcres  1987_TTLAcres  1992_TTLAcres  1997_TTLAcres  \
# 0       231.0         1548.0         1217.0         1011.0          968.0
# 1        10.0            NaN            NaN            NaN            2.0
# 2       496.0         1969.0         4881.0         5770.0         4003.0
# 3       153.0         2276.0         2120.0         1430.0         1048.0
# 4      2074.0        29933.0        34105.0        42024.0        49704.0
#
#    2002_TTLAcres  2007_TTLAcres  2002_FarmBear_Acres  2007_FarmBear_Acres  \
# 0          594.0          393.0                191.0                144.0
# 1           13.0           15.0                  8.0                 10.0
# 2         1581.0         1344.0                118.0                424.0
# 3          658.0          287.0                123.0                116.0
# 4        38268.0        22184.0               1850.0               1850.0
#
#    2002_Bear_Acres  2007_Bear_Acres
# 0            386.0            307.0
# 1              NaN              NaN
# 2           1459.0           1249.0
# 3            560.0            220.0
# 4          35856.0          20954.0

# %% [markdown]
# Next, tidy the data by melting the data. We have multiple variables in the header and we must melt them individually.  The best way to do this is to melt each variable separately, then combine them back to a single data frame.
#
# Do this, you will need to perform multiple melts:
# 1. First melt only the colums that have the number of farms and name the column `Farms`.
# 2. Second, melt only the columns that have the number of acres and name the column `Acres`.
# 3. Third, melt only the columns that have the number of bearing farms and name the column `Bearing_Farms`,
# 4. Fourth, melt only the columns that have the number of bearing acres and name the column `Bearing_Acres`.
#
# You'll also want to remove the prefix (e.g. "Farms-") from each value after melting and convert the 'Year' column to an integer.
#
# For example, after the first melt you should have a dataframe that looks like the following:
#
# |  | State | Year | Farms |
# | - | ----- | ---- | --------- |
# | 0 | Alabama | 1982 | 899 |
# | 1 | Alaska | 1982 | NaN |
# | 2 | Arizona | 1982 | 214 |
# | 3 | Arkansas | 1982 | 512 |
# | 4 | California | 1982 | 2904 |

# %% [markdown]
# Melt #1

# %%
apple_melt1 = pd.melt(apple, id_vars='State', var_name='Year_VarName',
                      value_name='Values', ignore_index=True)
apple_melt1.head()
# Out:
#         State Year_VarName  Values
# 0     Alabama   1982_Farms   899.0
# 1      Alaska   1982_Farms     NaN
# 2     Arizona   1982_Farms   214.0
# 3    Arkansas   1982_Farms   512.0
# 4  California   1982_Farms  2904.0

# %%
apple_melt1.shape
# Out:
# (800, 3)

# %%
split_df = apple_melt1['Year_VarName'].str.split('_', n=1, expand=True)
apple_melt2 = pd.concat([apple_melt1, split_df], axis=1)
apple_melt2.columns = ['State', 'Year_VarName', 'Value', 'Year', 'VarName']
apple_melt2.head()
# Out:
#         State Year_VarName   Value  Year VarName
# 0     Alabama   1982_Farms   899.0  1982   Farms
# 1      Alaska   1982_Farms     NaN  1982   Farms
# 2     Arizona   1982_Farms   214.0  1982   Farms
# 3    Arkansas   1982_Farms   512.0  1982   Farms
# 4  California   1982_Farms  2904.0  1982   Farms

# %%
apple_melt2.drop('Year_VarName', inplace=True, axis=1)
apple_melt2.head()
# Out:
#         State   Value  Year VarName
# 0     Alabama   899.0  1982   Farms
# 1      Alaska     NaN  1982   Farms
# 2     Arizona   214.0  1982   Farms
# 3    Arkansas   512.0  1982   Farms
# 4  California  2904.0  1982   Farms

# %%
apple_tidy = pd.pivot(apple_melt2, index=['State', 'Year'], columns = 'VarName', values='Value')
apple_tidy.head()
# Out:
# VarName       Bear_Acres  FarmBear_Acres  Farms  TTLAcres
# State   Year
# Alabama 1982         NaN             NaN  899.0    1548.0
#         1987         NaN             NaN  626.0    1217.0
#         1992         NaN             NaN  474.0    1011.0
#         1997         NaN             NaN  479.0     968.0
#         2002       386.0           191.0  265.0     594.0

# %%
apple_tidy.reset_index(inplace=True)
apple_tidy.head()
# Out:
# VarName    State  Year  Bear_Acres  FarmBear_Acres  Farms  TTLAcres
# 0        Alabama  1982         NaN             NaN  899.0    1548.0
# 1        Alabama  1987         NaN             NaN  626.0    1217.0
# 2        Alabama  1992         NaN             NaN  474.0    1011.0
# 3        Alabama  1997         NaN             NaN  479.0     968.0
# 4        Alabama  2002       386.0           191.0  265.0     594.0

# %% [markdown]
# Melt #2

# %% [markdown]
# Melt #3

# %% [markdown]
# Melt #4

# %% [markdown]
# Now combine all four melted dataframes into a single dataframe. To do this we can use the [pd.DataFrame.join()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.join.html) function. We will need to join one table at a time.
#
# Note: when you join tables they must have the same indexes. So, be sure to set the index of each dataframe before joining by using the [set_index()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.set_index.html) function.

# %%
# Set the indexes to be the same

# %%
# Join all of the tables.

# %% [markdown]
# What's the shape of the data now?

# %% [markdown]
# Do we have any duplicated rows now?

# %% [markdown]
# Now, do we want to remove missing values?

# %% [markdown]
# ### Explore the Data Again

# %% [markdown]
# Now that we have our data fully cleaned and tidy'ed let's explore it to make sure all looks good. First, we should still have 50 states. Can you find out?

# %% [markdown]
# How many years do we have per state? We should have the same number except for the states where we removed rows with missing values

# %% [markdown]
# Describe the data, but make sure it does so by state.
